# %% [markdown]
# # TP 5 Loi des grands nombres et mÃ©thode de Monte-Carlo

# %% [markdown]
# Importer numpy, le module stats de scipy et matplotlib.pyplot.
#
# DÃ©finir une variable `rng` contenant votre gÃ©nÃ©rateur de nombres alÃ©atoires.

# %% [markdown]
# ## Exercice 1 : Illustration de la LFGN

# %% [markdown]
# Nous allons illustrer dans cet exercice la loi forte des grands nombres pour la loi uniforme.
#
# On considÃ¨re une suite $(X_n)_{n\geq 1}$ de variables alÃ©atoires indÃ©pendantes, de loi uniforme sur $[a,b]$, et pour tout $n\ge1$, $$\bar X_n = \frac{1}{n}\sum_{i=1}^n X_i.$$
# 1. **Question thÃ©orique** Que dit la loi forte des grands nombres?  Quelle est la variance thÃ©orique de $\bar X_n$?

# %% [markdown]
# On souhaite illustrer la LFGN, lorsque $a=-4$, $b=8$ et $N=200$.
#
# 2. CrÃ©er un array `X` contenant un tirage $(x_1, \dots, x_N)$ du vecteur $(X_1, \dots, X_N)$, et un array `barX` contenant $(\bar x_k)_{1\leq k \leq N}$.

# %% [markdown]
# 3. ReprÃ©senter graphiquement `barX`.

# %% [markdown]
# 4. On prend maintenant  $N=50$. Simuler $M=10 000$ rÃ©alisations de $\bar X_N$, que l'on stockera dans un array.

# %% [markdown]
# 5. Reprendre la question 4  avec $a=-10$ et $b =14$.

# %% [markdown]
# 6. Tracer cÃ´te Ã  cÃ´te l'histogramme des densitÃ©s Ã  partir des rÃ©alisations de  $\bar X_N$ dans les deux exemples prÃ©cÃ©dents. Que constatez vous en terme de variance? D'autres remarques?

# %% [markdown]
# 7. Reprendre la question 6 avec $N=1000$. Que constatez vous ?

# %% [markdown]
# ## Exercice 2 MÃ©thode de Monte-Carlo
#
# Une application fondamentale de la LFGN est le calcul (approchÃ©) d'intÃ©grales par la mÃ©thode dite de **Monte-Carlo**.
#
# 1. **Un premier exemple (question thÃ©orique)** soit $f$ une fonction continue sur $[0,1]$. Ecrire sous la forme d'une espÃ©rance:
#
# $$\int_0^1 f(x) dx$$
#
# En dÃ©duire une mÃ©thode pour caculer une approximation de l'intÃ©grale.

# %% [markdown]
# 2. Appliquer la question 1 afin de calculer une approximation de
#
#     $$ I = \int_{0}^{1} \frac{dt}{1 + t^3}.$$

# %% [markdown]
# 3. On souhaite maintenant appliquer la mÃ©thode de Monte-Carlo pour calculer numÃ©riquement des valeurs de la fonction de rÃ©partition de la loi normale centrÃ©e rÃ©duite.
#
#     * **(question thÃ©orique)** Soit $X$ une variable alÃ©atoire de loi $\mathcal{N}(0,1)$. Pour $x\in  \mathbb R$, Ã©crire $\Phi(x) = \mathbb P(X\leq x)$ comme une espÃ©rance.
#     * En dÃ©duire une valeur approchÃ©e pour $\Phi(1.68)$ et $\Phi(1.96)$. Comparer avec les valeurs donnÃ©es par la mÃ©thode `cdf`de  `stats.norm`.

# %% [markdown]
# 4. DÃ©terminer des valeurs approchÃ©es de
#
# $$I =  \int_{-2}^{4} e^{-x^2}\, dx
# \qquad \text{et} \qquad
# J =\int_{0}^{+\infty} \frac{e^{-x}}{1 + x^4}\, dx.$$
#
# *Indication*: Pour $J$ on pourra utliser la loi exponentielle.
