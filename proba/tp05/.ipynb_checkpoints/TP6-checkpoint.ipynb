# %% [markdown]
# #  Illustration du thÃ©orÃ¨me central limite

# %% [markdown]
# On souhaite dans un premier temps illustrer le thÃ©orÃ¨me central limite.
#
# **Rappel** Soit $(X_n)_{n \ge 1}$ une suite de variables alÃ©atoires _i.i.d._ de carrÃ© intÃ©grable. On note $m=\mathbb E [X_1]$  et $\sigma^2 = Var (X_1)$, et pour tout $n \geq 1$,
#
# $$
#  \bar X_n = \frac{1}{n} \sum_{k=1}^n X_k.
# $$
# On veut illustrer la Loi Forte des Grands Nombres et le ThÃ©orÃ¨me Central Limite  c'est Ã  dire les convergences
#
# $$
#   \bar X_n \xrightarrow{p.s.} m \qquad \text{et} \qquad
#   \sqrt{n} \Bigl(\frac{\bar X_n - m}{\sigma}\Bigr) \xrightarrow{\mathcal{L}} \mathcal{N}(0, 1).
# $$

# %% [markdown]
# ## Exercice 1 : approximation gaussienne de la loi binomiale (dÃ©jÃ  vue en TD)
#
# Soit $p=0.45$, et $n \ge 1$ une entier. On note $S_n$ une variable alÃ©atoire suivant une loi $\mathcal B (n,p)$

# %% [markdown]
# 1. **Question thÃ©orique (de cours!)** Soit $(S_n^k)_{1\leq k \leq N}$, $N$ variables alÃ©atoires _i.i.d_ de loi $\mathcal B(n,p)$. Soit $0\leq j \leq n$. D'aprÃ¨s la loi des grands nombres, par quelle variable alÃ©atoire peut-on approcher $\mathbb P(S_n =j)$, avec $S_n$ une v.a. suivant une loi $\mathcal B(n,p)$.

# %% [markdown]
# 2. **Question thÃ©orique (de cours!)** Enoncer la formulation du thÃ©orÃ¨me central limite appliquÃ© Ã  $S_n$.   Quelle loi peut-Ãªtre utilisÃ©e pour approcher la loi de $S_n$?

# %% [markdown]
# 3. On prend $n=3$. Simuler $N$ variables alÃ©atoires $(S_n)_{1\leq n \leq N}$ indÃ©pendantes de loi $\mathcal B(n,p)$.

# %% [markdown]
# 4. A l'aide d'un diagramme en baton et de la question 3, reprÃ©senter graphiquement une approximation de la loi $\mathcal B(n,p)$.

# %% [markdown]
# 5. Comparer avec la loi de la question 2. L'approximation vous semble-t-elle valide?

# %% [markdown]
# 6. Reprendre la question 4 et 5 avec $n=10$, puis $n=100$, et comparer/interprÃ©ter les rÃ©sultats.
